# %%
import numpy as np
import pandas as pd
import os
import sys
sys.path.append('../')
from model import DecisionTree
from rule import RuleStatisticsCalculator

import warnings
warnings.filterwarnings(action='ignore')

# %%
# sage, srgnn 중 선택
embed_model = 'srgnn'
filename = {'sage' : 'user_embedding_sage_sid_6to6_weighted.npy', 'srgnn' : 'srgnn_user_hybrid_6to6_weighted.npy'}
data_path = "../data/"

pivot_df = pd.read_csv(os.path.join(data_path, 'pivot_genre2_data.csv'), index_col=0)
embedding = np.load(os.path.join(data_path, filename[embed_model]))

model = DecisionTree(pivot_df, embedding)
model.dt = model.make_dt(min_samples_leaf=25, min_impurity_decrease=0.0007)

# %%
rsc = RuleStatisticsCalculator(model, pivot_df)
df = rsc.calculate_statistics('../output/srgnn_rule', 'srgnn_seg_rule_extract')
df
# Out:
#     user_num  rule_num  depth_min  depth_max  depth_mean
# 0        528        14          6          9        8.36
# 1        490         8          4          8        5.25
# 2         42         1          4          4        4.00
# 3        296         8          5          7        6.50
# 4        584        15          4         12        7.27
# 5         88         2          7          7        7.00
# 6        409        11          6          9        7.45
# 7         79         2          5          5        5.00
# 8        260         6          6          9        7.83
# 9        505        10          6         11        8.70
# 10        75         3          7          9        7.67
# 11       141         4          6          9        7.50
# 12       546        14          6          9        7.79
# 13        70         2          6          8        7.00
# 14       695        17          4         12        8.82

# %%
rsc.plot_rule_distribution()
# Out:
# 0인 개수: 38
# 1100.55 이하인 개수: 721
# 0인 비율: 5.270 %
# 0인 개수: 145
# 331.3 이하인 개수: 1189
# 0인 비율: 12.195 %
# 0인 개수: 101
# 215.65 이하인 개수: 541
# 0인 비율: 18.669 %
# 0인 개수: 1621
# 35.15 이하인 개수: 2822
# 0인 비율: 57.442 %
# 0인 개수: 3686
# 0.25 이하인 개수: 3686
# 0인 비율: 100.000 %
# 0인 개수: 2278
# 0.25 이하인 개수: 2278
# 0인 비율: 100.000 %
# 0인 개수: 4137
# 0.3 이하인 개수: 4137
# 0인 비율: 100.000 %
# 0인 개수: 526
# 0.75 이하인 개수: 561
# 0인 비율: 93.761 %
# 0인 개수: 3330
# 20.45 이하인 개수: 3939
# 0인 비율: 84.539 %
# 0인 개수: 1399
# 1.5 이하인 개수: 1553
# 0인 비율: 90.084 %
# 0인 개수: 1167
# 0.8 이하인 개수: 1238
# 0인 비율: 94.265 %
# 0인 개수: 39
# 983.988 이하인 개수: 734
# 0인 비율: 5.313 %
# 0인 개수: 1422
# 105.4 이하인 개수: 3763
# 0인 비율: 37.789 %
# 0인 개수: 2553
# 0.9 이하인 개수: 2694
# 0인 비율: 94.766 %
# 0인 개수: 182
# 993.9 이하인 개수: 3043
# 0인 비율: 5.981 %
# 0인 개수: 1271
# 53.9 이하인 개수: 2726
# 0인 비율: 46.625 %
# 0인 개수: 26
# 1509.553 이하인 개수: 684
# 0인 비율: 3.801 %
# 0인 개수: 60
# 862.248 이하인 개수: 965
# 0인 비율: 6.218 %
# 0인 개수: 678
# 2.05 이하인 개수: 846
# 0인 비율: 80.142 %
# 0인 개수: 1752
# 1.15 이하인 개수: 2039
# 0인 비율: 85.924 %
# 0인 개수: 1070
# 1.5 이하인 개수: 1235
# 0인 비율: 86.640 %
# 0인 개수: 549
# 9.35 이하인 개수: 885
# 0인 비율: 62.034 %
